# %%
import matplotlib.pyplot as plt

data = [
  [
350,
400,
450,
500,
550,
600,
650,
700,
750
  ],
  [
60,
160,
560,
640,
700,
760,
840,
900,
960
  ]
]


plt.xlabel("High Voltage (V)")
plt.ylabel("Pulse Height (mV)")
plt.plot(data[0], data[1], 'ok--')
plt.grid()
plt.savefig("e01p2.png", dpi=300)
