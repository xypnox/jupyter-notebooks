# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.constants import k,e #in SI
fig, graph = plt.subplots()



x = [

12.50,
12.55,
12.60,
12.65,
12.70,
12.75,
12.80,
12.85,
12.90,
12.95,
13.00,
13.05,
13.10,
13.15,
13.20,
13.25,
13.30,
13.35,
13.40,
13.45,
13.50,
13.55,
13.60,
13.70,
13.75,
13.80,
13.85,
13.90,
13.95,
14.00,
14.05,
14.10,
14.15,
14.20,
14.25,
14.30,
14.35,
14.40,
14.45,
14.50,
14.55,
14.60,
14.65,
14.70,
14.75,
14.80,


] 
y= [


0,
0,
0.1,
0.2,
0.2,
0.4,
0.5,
0.8,
1.2,
2.0,
3.3,
5.3,
8.4,
14.3,
23.3,
37.8,
53.9,
70.6,
82.7,
95.8,
107.4,
117.9,
128.2,
144.7,
150.3,
152.80,
151.9,
146.1,
138.3,
127.2,
113.0,
93.7,
72.6,
53.8,
37.7,
23.9,
15.4,
9.4,
6.0,
4.0,
2.4,
1.3,
0.6,
0.3,
0.1,
0.1,



]

# %%
graph.scatter(x, y)
graph.grid()
graph.set(
    xlabel = "Micrometer reading",
    ylabel = "O/P Current uA",
    title  = "Output current along Y direction (Z = 3mm)"
)

fig.savefig('singlemode-yaxis.png', dpi = 300)
fig
