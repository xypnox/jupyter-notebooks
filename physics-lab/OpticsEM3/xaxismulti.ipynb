# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.constants import k,e #in SI
fig, graph = plt.subplots()



x = [
5.5, 
6.8, 
7.0, 
7.5, 
8.0, 
8.25, 
8.5, 
8.75, 
9.0, 
9.5, 
10.0, 
10.5, 
10.75, 
10.8, 
10.9, 
10.95, 
11.0, 
11.05, 
11.10, 
11.15, 
11.20, 
11.25, 
11.30, 
11.35, 
11.40, 
11.45, 
11.50, 
11.55, 
11.60, 
11.65, 
11.70, 
11.75, 
11.80, 
11.85, 
11.90, 
11.95, 
12.00, 
12.50, 
13.90, 
13.95, 
14.00, 
14.05, 
14.10, 
14.15, 
14.25, 
14.30, 
14.35, 
14.40, 
14.45, 
14.50, 
14.60, 
14.70, 
14.75, 
14.85, 
14.95, 
15.10, 
15.35, 
15.50, 
16.00, 
17.00
] 
y= [
    10**(-3)*0.1,
10**(-3)*0.2,
10**(-3)*0.2,
10**(-3)*0.4,
10**(-3)*0.7,
10**(-3)*0.9,
10**(-3)*1.1,
10**(-3)*1.6,
10**(-3)*2.1,
10**(-3)*3.5,
10**(-3)*6.7,
10**(-3)*16.4,
10**(-3)*41.2,
10**(-3)*52.2,
10**(-3)*83.3,
10**(-3)*101.8,
10**(-3)*127.9,
10**(-3)*159.6,
10**(-3)*197.9,
0.1,
0.2,
0.3,
0.4,
0.6,
0.8,
1.0,
1.3,
1.5,
1.8,
2.0,
2.3,
2.6,
2.8,
3.0,
3.2,
3.3,
3.3,
3.4,
3.2,
3.1,
2.4,
2.6,
2.4,
2.1,
1.5,
1.2,
1.0,
0.7,
0.5,
0.4,
0.2,
0.1,
10**(-3)*93.2,
10**(-3)*56.3,
10**(-3)*35.5,
10**(-3)*19.5,
10**(-3)*10.4,
10**(-3)*8.4,
10**(-3)*4.8,
10**(-3)*1.0
]

# %%
graph.scatter(x, y)
graph.grid()
graph.set(
    xlabel = "Distance",
    ylabel = "O/P current",
    title  = "X - Axis"
)

fig.savefig('xaxis.png', dpi = 300)
fig
