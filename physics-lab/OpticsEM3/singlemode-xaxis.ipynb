# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.constants import k,e #in SI
fig, graph = plt.subplots()



x = [

12.45,
12.50,
12.60,
12.70,
12.75,
12.80,
12.85,
12.90,
12.95,
13.00,
13.05,
13.10,
13.15,
13.20,
13.25,
13.30,
13.35,
13.40,
13.45,
13.50,
13.55,
13.60,
13.65,
13.70,
13.75,
13.80,
13.85,
13.90,
13.95,
14.00,
14.05,
14.10,
14.15,
14.20,
14.25,
14.30,
14.35,
14.40,
14.45,
14.50,
14.55,
14.60,
14.65,
14.70,


] 
y= [


0,
0.1,
0.5,
1.8,
4.1,
11.3,
25.1,
44.0,
63.90,
80.2,
93.5,
103.3,
110.4,
115.3,
119.0,
121.4,
125.1,
126.9,
128.3,
128.5,
128.3,
128.0,
127.0,
126.1,
124.3,
119.1,
110.5,
106.5,
87.9,
76.1,
61.2,
45.50,
32.1,
21.7,
14.2,
9.6,
6.4,
4.0,
2.5,
1.5,
0.8,
0.4,
0.2,
0.1,


]

# %%
graph.scatter(x, y)
graph.grid()
graph.set(
    xlabel = "Micrometer reading",
    ylabel = "O/P Current uA",
    title  = "Output current along X direction (Z = 3mm)"
)

fig.savefig('singlemode.png', dpi = 300)
fig
