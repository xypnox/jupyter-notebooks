# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.constants import k,e #in SI
fig, graph = plt.subplots()



x = [

4.5,
4.75,
5.0,
5.25,
5.50,
5.75,
6.00,
6.25,
6.50,
6.75,
7.0,
7.25,
7.5,
7.75,
8.00,
8.50,
9.00,
10.00,
11.00,
12.00,
13.00,
14.00,
15.00,
16.00
] 
y= [
    21.30,
19.80,
17.60,
15.50,
13.10,
11.40,
9.70,
8.30,
7.00,
5.90,
5.20,
4.70,
4.0,
3.50,
3.10,
2.60,
2.0,
1.3,
1.0,
0.8,
0.6,
0.5,
0.4,
0.3

]

# %%
graph.scatter(x, y)
graph.grid()
graph.set(
    xlabel = "Distance mm",
    ylabel = "O/P current uA",
    title  = "Longitudinal"
)

fig.savefig('longt.png', dpi = 300)
fig
