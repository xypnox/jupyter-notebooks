# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.constants import k,e #in SI
fig, graph = plt.subplots()



x = [
14.95,
14.90,
14.85,
14.80,
14.75,
14.70,
14.65,
14.60,
14.55,
14.50,
14.45,
14.40,
14.35,
14.30,
14.25,
14.20
] 
y= [
26.5,
25.8,
23.1,
19.2,
16.4,
13.8,
11.9,
8.8,
7.8,
3.2,
1.5,
0.6,
0.3,
0.1,
0.1,
0
]

# %%
graph.scatter(x, y)
graph.grid()
graph.set(
    xlabel = "Distance mm",
    ylabel = "O/P current uA",
    title  = "transverse"
)

fig.savefig('trans.png', dpi = 300)
fig
