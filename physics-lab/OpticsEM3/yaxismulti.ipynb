# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.constants import k,e #in SI
fig, graph = plt.subplots()



x = [
13.5,
14.0,
14.5,
15.0,
15.25,
15.5,
15.6,
15.75,
15.80,
15.9,
16.0,
16.1,
16.2,
16.3,
16.4,
16.5,
16.6,
17.0,
17.1,
17.5,
17.6,
17.8,
18.0,
18.1,
18.3,
18.4,
18.5,
18.6,
18.7,
18.8,
18.9,
19.0,
19.1,
19.2,
19.3,
19.4,
19.5,
19.7,
20.00,
20.5,
21.5

] 
y= [
1.0 * 10**(-3),
1.7 * 10**(-3),
3.6 * 10**(-3),
10.0 * 10**(-3),
20.8 * 10**(-3),
55.6 * 10**(-3),
101.7 * 10**(-3),
0.2,
0.3,
0.6,
1.0,
1.6,
2.1,
2.6,
3.0,
3.3,
3.4,
3.4,
3.3,
3.4,
3.5,
3.6,
3.6,
3.7,
3.8,
3.7,
3.4,
2.9,
2.3,
1.7,
1.1,
0.7,
0.4,
0.2,
0.1,
84.9 * 10 ** (-3),
7.5 * 10 ** (-3),
19.4 * 10 ** (-3),
7.4 * 10 ** (-3),
2.8 * 10 ** (-3),
1.0 * 10 ** (-3)
]

# %%
graph.scatter(x, y)
graph.grid()
graph.set(
    xlabel = "Distance",
    ylabel = "O/P current",
    title  = "Y - Axis"
)

fig.savefig('yaxismulti.png', dpi = 300)
fig
