# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.constants import k,e #in SI
fig, graph = plt.subplots()



x = [
0,
0.5,
0.75,
0.9,
0.95,
1,
1.10,
1.20,
1.30,
1.40,
1.50,
1.60,
1.70,
1.80,
1.9,
2.0,
2.1,
2.2,
2.3,
2.4,
2.5,
2.6,
2.7,
2.8,
2.9,
3.0,

] 
y1 = [


0,
0,
0,
0.02,
0.06,
0.11,
0.28,
0.50,
0.75,
1.0,
1.28,
1.56,
1.83,
2.08,
2.38,
2.67,
2.96,
3.24,
3.53,
3.82,
4.09,
4.39,
4.70,
4.98,
5.25,
5.55

] 
y2 = [


0,
0,
0,
0,
0.01,
0.03,
0.16,
0.42,
0.80,
1.24,
1.76,
2.34,
2.93,
3.50,
4.16,
4.81,
5.49,
6.15,
6.81,
7.51,
8.15,
8.84,
9.54,
10.22,
10.83,
11.51,
    
]

# %%
graph.plot(x, y1, 'g.--', label="Input Current")
graph.plot(x, y2, 'b.--', label="Output Current")
graph.legend(loc="upper left")
graph.grid()
graph.set(
    xlabel = "Input Voltage",
    ylabel = "Current",
    title  = "Response Characteristics of a Optocoupler"
)


fig.savefig('Response Characteristics of a optocoupler.png', dpi = 300)
fig
