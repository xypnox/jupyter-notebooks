# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.constants import k,e #in SI
fig, graph = plt.subplots()



x = [
0,
0.25,
0.50,
0.75,
1,
1.25,
1.50,
1.75,
2,
2.25,
2.50,
2.75,
3,
3.25,
3.50,
3.75,
4,
4.25,
4.50,
4.75,
5

] 
y= [
    0,
0.13,
0.25,
0.38,
0.50,
0.63,
0.76,
0.89,
1.02,
1.15,
1.28,
1.40,
1.54,
1.66,
1.80,
1.92,
2.06,
2.19,
2.32,
2.46,
2.59
]

# %%
graph.scatter(x, y)
graph.grid()
graph.set(
    xlabel = "Voltage",
    ylabel = "Current",
    title  = "Voltage across  LDR vs current flowing through LDR"
)

fig.savefig('ldr.png', dpi = 300)
fig
