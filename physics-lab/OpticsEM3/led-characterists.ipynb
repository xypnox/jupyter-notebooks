# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.constants import k,e #in SI
fig, graph = plt.subplots()



x = [

0,
0.20,
0.38,
0.48,
0.62,
0.71,
0.79,
0.91,
0.98,
1.08,
1.19,
1.29,
1.5,
1.66,
1.75,
1.85,
1.95,
2.04,
2.15,
2.2,
2.25,
2.31,
2.41,
2.5,



] 
y = [

0,
0.02,
0.04,
0.05,
0.06,
0.07,
0.08,
0.09,
0.10,
0.11,
0.12,
0.13,
0.16,
0.18,
0.23,
0.50,
1.73,
8.57,
95.6,
198.9,
450,
900,
1870,
3060,


]

# %%
graph.scatter(x, y)
graph.grid()
graph.set(
    xlabel = "Voltage (Volts)",
    ylabel = "Current (uA)",
    title  = "Characteristics of an LED"
)


fig.savefig('led-characteristics.png', dpi = 300)
fig
